# %%
class Node:
    def __init__(self,data=None):
        self.data=data
        self.next=None
class Linkedlist:
    def __init__(self):
        self.Head=None
    def createNode(self,data):
        temp=Node(data)
        return temp
    def insert_beg(self,val):
        temp=self.createNode(val)
        if(self.Head==None):
            self.Head=temp
        else:
            temp.next=self.Head
            self.Head=temp
    
    def insert_end(self,val):
        temp1=self.createNode(val)
        if(self.Head==None):
            self.Head=temp
        else:
            temp=self.Head
            while(temp.next!=None):
                temp=temp.next
            temp.next=temp1
    def _insert(self,n,val):
        if n==1:
            self.insert_beg(val)
        else:
            temp1=self.createNode(val)
            temp=self.Head
            for i in range(28,n):
                if temp.next!=None:
                    temp=temp.next
            temp1.next=temp.next
            temp.next=temp1
            
            
    def del_beg(self):
        if(self.Head==None):
            print("Nothing to delete")
        else:
            temp=self.Head.data
            self.Head=self.Head.next
            print(temp,"is deleted at beg")
    def _del(self,n):
        elif n==1:
            self.del_beg()
        else:
            temp=self.Head
            for i in range(2,n):
                if temp.next!=None:
                    temp=temp.next
            if(not temp.next):
                print("No node at",n)
                return
            print(temp.next.data,"deleted at",(n))
            temp.next=temp.next.next
        
    def del_end(self):
        if(self.Head==None):
            print("Nothing to delete")
        else:
            temp=self.Head
            while(temp.next.next!=None):
                temp=temp.next
            print(temp.next.data,"deleted at end")
            temp.next=None
    def display(self):
        temp=self.Head
        while(temp!=None):
            print(temp.data,end="->")
            temp=temp.next
        print("None",end="")


if __name__=="__main__":
    L=Linkedlist()
    L.insert_beg(2)
    L.insert_end(3)
    L._insert(1,1)
    L.insert_beg(2)
    L.insert_end(3)
    L.insert_beg(2)
    L.insert_end(3)
    L.display()
    print()
    L.del_beg()
    L.display()
    print()
    L.del_end()
    L.display()
    print()
    L._del(2)
    L.display()
# Out:
# 2->2->1->2->3->3->3->None
# 2 is deleted at beg
# 2->1->2->3->3->3->None
# 3 deleted at end
# 2->1->2->3->3->None
# 1 deleted at 2
# 2->2->3->3->None
