# %%
# dfs
class Graph:
    def __init__(self):
        self.graph = {}

    def add_edge(self, u, v):
        if u not in self.graph:
            self.graph[u] = []
        self.graph[u].append(v)

    def print_adjacency_list(self):
        print("Adjacency List:")
        for vertex in self.graph:
            print(f"{vertex}: {self.graph[vertex]}")

    def dfs(self, start_vertex, visited=None):
        if visited is None:
            visited = set()

        if start_vertex not in visited:
            visited.add(start_vertex)
            print(f"Visiting vertex {start_vertex}", end=" -> ")

            for neighbour in self.graph[start_vertex]:
                self.dfs(neighbour, visited)

# Create an instance of the Graph class
g = Graph()

# Add edges to the graph
g.add_edge(1, 2)
g.add_edge(1, 3)
g.add_edge(1, 10)
g.add_edge(2, 1)
g.add_edge(2, 4)
g.add_edge(3, 1)
g.add_edge(3, 7)
g.add_edge(4, 2)
g.add_edge(4, 5)
g.add_edge(4, 7)
g.add_edge(4, 8)
g.add_edge(5, 4)
g.add_edge(5, 6)
g.add_edge(6, 5)
g.add_edge(6, 9)
g.add_edge(6, 10)
g.add_edge(7, 3)
g.add_edge(7, 4)
g.add_edge(7, 11)
g.add_edge(8, 4)
g.add_edge(8, 9)
g.add_edge(9, 6)
g.add_edge(9, 8)
g.add_edge(10, 1)
g.add_edge(10, 6)
g.add_edge(11, 7)

# Print the adjacency list of the graph
g.print_adjacency_list()

# Perform Depth First Search starting from the first vertex in the graph
print("\nDepth First Search:")
g.dfs(list(g.graph.keys())[0])
# Out:
# Adjacency List:
# 1: [2, 3, 10]
# 2: [1, 4]
# 3: [1, 7]
# 4: [2, 5, 7, 8]
# 5: [4, 6]
# 6: [5, 9, 10]
# 7: [3, 4, 11]
# 8: [4, 9]
# 9: [6, 8]
# 10: [1, 6]
# 11: [7]
#
# Depth First Search:
# Visiting vertex 1 -> Visiting vertex 2 -> Visiting vertex 4 -> Visiting vertex 5 -> Visiting vertex 6 -> Visiting vertex 9 -> Visiting vertex 8 -> Visiting vertex 10 -> Visiting vertex 7 -> Visiting vertex 3 -> Visiting vertex 11 ->

# %%
# bfs
from collections import deque

class Graph:
    def __init__(self):
        self.graph = {}

    def add_edge(self, u, v):
        if u not in self.graph:
            self.graph[u] = []
        self.graph[u].append(v)

    def print_adjacency_list(self):
        print("Adjacency List:")
        for vertex in self.graph:
            print(f"{vertex}: {self.graph[vertex]}")

    def bfs(self, start_vertex):
        visited = set()
        queue = deque([start_vertex])

        print("Breadth First Search:")
        while queue:
            vertex = queue.popleft()
            if vertex not in visited:
                visited.add(vertex)
                print(f"Visiting vertex {vertex}", end=" -> ")

                for neighbour in self.graph[vertex]:
                    if neighbour not in visited:
                        queue.append(neighbour)

# Create an instance of the Graph class
g = Graph()
g.add_edge(1, 2)
g.add_edge(1, 3)
g.add_edge(1, 10)
g.add_edge(2, 1)
g.add_edge(2, 4)
g.add_edge(3, 1)
g.add_edge(3, 7)
g.add_edge(4, 2)
g.add_edge(4, 5)
g.add_edge(4, 7)
g.add_edge(4, 8)
g.add_edge(5, 4)
g.add_edge(5, 6)
g.add_edge(6, 5)
g.add_edge(6, 9)
g.add_edge(6, 10)
g.add_edge(7, 3)
g.add_edge(7, 4)
g.add_edge(7, 11)
g.add_edge(8, 4)
g.add_edge(8, 9)
g.add_edge(9, 6)
g.add_edge(9, 8)
g.add_edge(10, 1)
g.add_edge(10, 6)
g.add_edge(11, 7)



# Print the adjacency list of the graph
g.print_adjacency_list()

# Perform Breadth First Search starting from the first vertex in the graph
g.bfs(list(g.graph.keys())[0])
# Out:
# Adjacency List:
# 1: [2, 3, 10]
# 2: [1, 4]
# 3: [1, 7]
# 4: [2, 5, 7, 8]
# 5: [4, 6]
# 6: [5, 9, 10]
# 7: [3, 4, 11]
# 8: [4, 9]
# 9: [6, 8]
# 10: [1, 6]
# 11: [7]
# Breadth First Search:
# Visiting vertex 1 -> Visiting vertex 2 -> Visiting vertex 3 -> Visiting vertex 10 -> Visiting vertex 4 -> Visiting vertex 7 -> Visiting vertex 6 -> Visiting vertex 5 -> Visiting vertex 8 -> Visiting vertex 11 -> Visiting vertex 9 ->
