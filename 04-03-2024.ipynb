# %%
aList = [[],[],[],[],[]]

print(aList)

def add1(s,d,aList):
    aList[s].append(d)
    
def bfs(s,aList):
    queue=list()
    visited = set()
    queue.append(s)
    
    for i in queue:
        if i not in visited:
                
            print(i,end="")
            visited.add(i)
            for j in aList[i]:
                queue.append(j)
                queue.pop()
    
   
      
        
add1(0,1,aList)
add1(0,3,aList)
add1(0,4,aList)
add1(1,0,aList)
add1(1,2,aList)

add1(2,1,aList)

add1(2,4,aList)
add1(3,0,aList)
add1(4,0,aList)

add(4,2,aList)

bfs(0,aList)

# %%
class Graph:
    def __init__(self, v):
        self.v = v
        self.adj_list = [[] for _ in range(v)]
        self.visited=set()

    def add_edge(self, s, d, w):
        self.adj_list[s - 1].append((s, d, w))

    def display_graph(self):
        print(self.adj_list)
        for vertex in range(self.v):
            neighbors = self.adj_list[vertex]
            print(f"Vertex {vertex + 1}: {neighbors}")

    def dfs(self,vertex):   
        for neighbor in self.adj_list[vertex - 1]:
            if neighbor not in self.visited:
                self.dfs(neighbor)
                print(vertex,end="")
                self.visited.add(vertex)
            
                    
        


graph = Graph(5)
graph.add_edge(1, 2, 0)
graph.add_edge(1, 5, 0)
graph.add_edge(1, 3, 0)
graph.add_edge(2, 1, 0)
graph.add_edge(2, 4, 0)
graph.add_edge(3, 1, 0)
graph.add_edge(4, 2, 0)
graph.add_edge(5, 1, 0)

graph.display_graph()
graph.dfs(1)

# %%
class Graph:
    def __init__(self, v):
        self.v = v
        self.adj_list = [[] for _ in range(v)]
        self.visited = set()

    def add_edge(self, s, d, w):
        self.adj_list[s - 1].append((s, d, w))

    def display_graph(self):
        print(self.adj_list)
        for vertex in range(self.v):
            neighbors = self.adj_list[vertex]
            print(f"Vertex {vertex + 1}: {neighbors}")

    def dfs(self, vertex):
        for neighbor in self.adj_list[vertex - 1]:
            if neighbor not in self.visited:
                self.dfs(neighbor)  # Fix here: use self.dfs instead of dfs
                print(vertex, end="")
                self.visited.add(vertex)  # Fix here: use self.visited instead of visited


graph = Graph(5)
graph.add_edge(1, 2, 0)
graph.add_edge(1, 5, 0)
graph.add_edge(1, 3, 0)
graph.add_edge(2, 1, 0)
graph.add_edge(2, 4, 0)
graph.add_edge(3, 1, 0)
graph.add_edge(4, 2, 0)
graph.add_edge(5, 1, 0)

graph.display_graph()
graph.dfs(1)
# Out:
# [[(1, 2, 0), (1, 5, 0), (1, 3, 0)], [(2, 1, 0), (2, 4, 0)], [(3, 1, 0)], [(4, 2, 0)], [(5, 1, 0)]]
# Vertex 1: [(1, 2, 0), (1, 5, 0), (1, 3, 0)]
# Vertex 2: [(2, 1, 0), (2, 4, 0)]
# Vertex 3: [(3, 1, 0)]
# Vertex 4: [(4, 2, 0)]
# Vertex 5: [(5, 1, 0)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 35>()
#      32 graph.add_edge(5, 1, 0)
#      34 graph.display_graph()
# ---> 35 graph.dfs(1)
#
# Input In [1], in Graph.dfs(self, vertex)
#      17 for neighbor in self.adj_list[vertex - 1]:
#      18     if neighbor not in self.visited:
# ---> 19         self.dfs(neighbor)  # Fix here: use self.dfs instead of dfs
#      20         print(vertex, end="")
#      21         self.visited.add(vertex)
#
# Input In [1], in Graph.dfs(self, vertex)
#      16 def dfs(self, vertex):
# ---> 17     for neighbor in self.adj_list[vertex - 1]:
#      18         if neighbor not in self.visited:
#      19             self.dfs(neighbor)  # Fix here: use self.dfs instead of dfs
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'int'

# %%
class Graph:
    def __init__(self, v):
        self.v = v
        self.adj_list = [[] for _ in range(v)]
        self.visited = set()

    def add_edge(self, s, d, w):
        self.adj_list[s - 1].append((s, d, w))

    def display_graph(self):
        print(self.adj_list)
        for vertex in range(self.v):
            neighbors = self.adj_list[vertex]
            print(f"Vertex {vertex + 1}: {neighbors}")

    def dfs(self, vertex):
        for edge in self.adj_list[vertex - 1]:
            neighbor = edge[1]  # Extract the destination vertex from the tuple
            if neighbor not in self.visited:
                self.dfs(neighbor)
                print(vertex, end="")
                self.visited.add(vertex)


graph = Graph(5)
graph.add_edge(1, 2, 0)
graph.add_edge(1, 5, 0)
graph.add_edge(1, 3, 0)
graph.add_edge(2, 1, 0)
graph.add_edge(2, 4, 0)
graph.add_edge(3, 1, 0)
graph.add_edge(4, 2, 0)
graph.add_edge(5, 1, 0)

graph.display_graph()
graph.dfs(1)
